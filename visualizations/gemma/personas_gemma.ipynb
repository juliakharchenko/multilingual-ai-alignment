# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # SCATTERPLOT VISUALIZATIONS

# %% [markdown]
# ## Individualism vs Collectivism

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_individualistic_collectivist.csv"
data = pd.read_csv(file_path)


# Calculate the percentage of individualistic responses for each country
individualistic_percentage = (data[data['Matching_Choice'] == 'Individualistic'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100

import scipy
print(scipy.stats.pearsonr(data['Individualistic_Collectivist_Score'], individualistic_percentage[data['Target_Nationality']], alternative='two-sided', method=None))

# Plot the scatterplot with linear regression
plt.figure(figsize=(10, 6))
sns.regplot(x=data['Individualistic_Collectivist_Score'], y=individualistic_percentage[data['Target_Nationality']], ci=None)
plt.title('Country Individualistic Value vs. \n% Individualistic Responses', fontsize=25)
plt.xlabel('Country Individualistic Value', fontsize=25)
plt.ylabel('% Individualistic\n Responses', fontsize=25)
plt.grid(True)
plt.show()
# Out:
# PearsonRResult(statistic=0.31875234019335175, pvalue=8.647596074882255e-44)

# %% [markdown]
# ## MAS

# %%
# Load the data from the input file
file_path = "/content/output_gemma_it_personas_mas.csv"
data = pd.read_csv(file_path)

# Calculate the percentage of individualistic responses for each country
individualistic_percentage = (data[data['Matching_Choice'] == 'Masculine'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100

import scipy
print(scipy.stats.pearsonr(individualistic_percentage[data['Target_Nationality']], data['MAS_Score'], alternative='two-sided', method=None))

# Plot the scatterplot with linear regression
plt.figure(figsize=(10, 6))
sns.regplot(x=data['MAS_Score'], y=individualistic_percentage[data['Target_Nationality']], ci=None)
plt.title('Country MAS Value vs. % High MAS Responses', fontsize=25)
plt.xlabel('Country MAS Score', fontsize=25)
plt.ylabel('% High MAS Responses', fontsize=25)
plt.grid(True)
plt.show()
# Out:
# PearsonRResult(statistic=0.2584080839950495, pvalue=7.528719369313719e-29)

# %% [markdown]
# ## Orientation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_orientation.csv"
data = pd.read_csv(file_path)

# Calculate the percentage of individualistic responses for each country
individualistic_percentage = (data[data['Matching_Choice'] == 'Long Term'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100
print(scipy.stats.pearsonr(individualistic_percentage[data['Target_Nationality']], data['Long_Term_Orientation_Score'], alternative='two-sided', method=None))

# Plot the scatterplot with linear regression
plt.figure(figsize=(10, 6))
sns.regplot(x=data['Long_Term_Orientation_Score'], y=individualistic_percentage[data['Target_Nationality']], ci=None)
plt.title('Country Long Term Orientation Value vs. \n% Long Term Orientation Responses', fontsize=25)
plt.xlabel('Country Long Term Orientation Value', fontsize=25)
plt.ylabel('% Long Term \nOrientation Responses', fontsize=25)
plt.grid(True)
plt.show()
# Out:
# PearsonRResult(statistic=0.060645799844412956, pvalue=0.010065673643792787)

# %% [markdown]
# ## PDI

# %%
# Load the data from the input file
import scipy
file_path = "/content/output_gemma_it_personas_power_distance.csv"
data = pd.read_csv(file_path)

# Calculate the percentage of individualistic responses for each country
individualistic_percentage = (data[data['Matching_Choice'] == 'Low Power Distance'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100
print(scipy.stats.pearsonr(individualistic_percentage[data['Target_Nationality']], data['Power_Distance_Index_Score'], alternative='two-sided', method=None))

# Plot the scatterplot with linear regression
plt.figure(figsize=(10, 6))
sns.regplot(x=data['Power_Distance_Index_Score'], y=individualistic_percentage[data['Target_Nationality']], ci=None)
plt.title('Country PDI Score vs. % Low PDI Responses', fontsize=25)
plt.xlabel('Country PDI Score', fontsize=25)
plt.ylabel('% Low PDI Responses', fontsize=25)
plt.grid(True)
plt.show()
# Out:
# PearsonRResult(statistic=-0.2410373487076587, pvalue=3.3059685728150406e-25)

# %% [markdown]
# ## UNCERTAINTY

# %%
# Load the data from the input file
file_path = "/content/output_gemma_it_personas_uncertainty.csv"
data = pd.read_csv(file_path)

# Calculate the percentage of individualistic responses for each country
individualistic_percentage = (data[data['Matching_Choice'] == 'High Uncertainty Avoidance'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100
print(scipy.stats.pearsonr(individualistic_percentage[data['Target_Nationality']], data['Uncertainty_Avoidance_Score'], alternative='two-sided', method=None))

# Plot the scatterplot with linear regression
plt.figure(figsize=(10, 6))
sns.regplot(x=data['Uncertainty_Avoidance_Score'], y=individualistic_percentage[data['Target_Nationality']], ci=None)
plt.title('Country Uncertainty Avoidance Value vs. \n% High Uncertainty Avoidance Responses', fontsize=25)
plt.xlabel('Country Uncertainty Avoidance Value', fontsize=25)
plt.ylabel('% High Uncertainty \nAvoidance Responses', fontsize=25)
plt.grid(True)
plt.show()
# Out:
# PearsonRResult(statistic=0.03191533228668924, pvalue=0.17590966861450388)

# %% [markdown]
# #WIN RATES

# %% [markdown]
# ## INDIVIDUALISM VS COLLECTIVISM

# %%
file_path = "/content/output_gemma_it_personas_individualistic_collectivist.csv"
data = pd.read_csv(file_path)

# Calculate the win rate (percentage of individualistic responses) for each country
win_rate = (data[data['Matching_Choice'] == 'Individualistic'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100

# Sort the win rate values for better visualization
win_rate = win_rate.sort_values()
print(len(win_rate))

collectivist_countries = ['Russia', 'China', 'Indonesia', 'Turkey', 'Poland', 'Iran',
                          'Romania', 'Thailand', 'Bulgaria', 'Kazakhstan', 'Armenia',
                          'Georgia', 'Albania', 'Azerbaijan', 'Malaysia', 'Mongolia',
                          'Belarus', 'India', 'South Africa', 'Sri Lanka']  # List of collectivist countries

# Define colors based on whether the target nationalities are individualistic or collectivist
colors = []
for country in win_rate.index:
    if country in collectivist_countries:
        colors.append('green')
    else:
        colors.append('orange')

# Plot the horizontal bar plot
plt.figure(figsize=(10, 8))
win_rate.plot(kind='barh', color=colors)
plt.title('Individualistic Response Rate by Country')
plt.xlabel('Individualistic Response Rate (%)')
plt.ylabel('Country')
legend_labels = ['Collectivist Country', 'Individualistic Country']
legend_colors = ['green', 'orange']
legend_handles = [plt.Rectangle((0,0),1,1, color=color) for color in legend_colors]
plt.legend(legend_handles, legend_labels, loc='upper left', bbox_to_anchor=(1, 1.1))
plt.grid(axis='x')
# Add win rate percentages on each bar
for i, v in enumerate(win_rate):
    plt.text(v + 0.5, i, f'{v:.2f}%', color='black', va='center')
plt.show()
# Out:
# 36

# %% [markdown]
# ## MAS

# %%
file_path = "/content/output_gemma_it_personas_mas.csv"
data = pd.read_csv(file_path)

# Calculate the win rate (percentage of individualistic responses) for each country
win_rate = (data[data['Matching_Choice'] == 'Masculine'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100

# Sort the win rate values for better visualization
win_rate = win_rate.sort_values()
print(len(win_rate))

collectivist_countries = ['The United States', 'Germany', 'Italy', 'Hungary', 'South Africa', 'Japan', 'Poland', 'Czechia',
                          'Greece', 'Georgia', 'Albania', 'India']  # List of collectivist countries

# Define colors based on whether the target nationalities are individualistic or collectivist
colors = []
for country in win_rate.index:
    if country in collectivist_countries:
        colors.append('green')
    else:
        colors.append('orange')

# Plot the horizontal bar plot
plt.figure(figsize=(10, 8))
win_rate.plot(kind='barh', color=colors)
plt.title('High MAS Response Rate by Country')
plt.xlabel('High MAS Response Rate (%)')
plt.ylabel('Country')
legend_labels = ['High MAS Country', 'Low MAS Country']
legend_colors = ['green', 'orange']
legend_handles = [plt.Rectangle((0,0),1,1, color=color) for color in legend_colors]
plt.legend(legend_handles, legend_labels, loc='upper left', bbox_to_anchor=(1, 1.1))
plt.grid(axis='x')
# Add win rate percentages on each bar
for i, v in enumerate(win_rate):
    plt.text(v + 0.5, i, f'{v:.2f}%', color='black', va='center')
plt.show()
# Out:
# 36

# %% [markdown]
# ## ORIENTATION

# %%
file_path = "/content/output_gemma_it_personas_orientation.csv"
data = pd.read_csv(file_path)

# # Calculate the win rate (percentage of individualistic responses) for each country
# win_rate = (data[data['Matching_Choice'] == 'Masculine'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100
# win_rate_2 = (data[data['Matching_Choice'] == 'Feminine'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100
# Group by 'Target_Nationality' and 'Matching_Choice', then calculate the size of each group
grouped_data = data.groupby(['Target_Nationality', 'Matching_Choice']).size()
print(grouped_data)

# Pivot the table to make 'Matching_Choice' values as columns and fill missing values with 0
pivot_table = grouped_data.unstack(fill_value=0)

# Calculate the win rate (percentage of occurrences) for each country
win_rate = (pivot_table['Long Term'] / (pivot_table['Long Term'] + pivot_table['Short Term'])) * 100

# Sort the win rate values for better visualization
win_rate = win_rate.sort_values()

high_long_term_countries =  ['Germany', 'Russia', 'Japan', 'France', 'China', 'The Netherlands', 'South Korea',
                             'Czech Republic', 'Ukraine', 'Greece', 'Sweden', 'Denmark', 'Thailand', 'Finland',
                             'Bulgaria', 'Kazakhstan', 'Albania', 'Azerbaijan', 'Belarus', 'India', 'Iceland']
 # List of collectivist countries

# Define colors based on whether the target nationalities are individualistic or collectivist
colors = []
for country in win_rate.index:
    if country in high_long_term_countries:
        colors.append('green')
    else:
        colors.append('orange')

# Plot the horizontal bar plot
plt.figure(figsize=(10, 8))
win_rate.plot(kind='barh', color=colors)
plt.title('Long Term Orientation Response Rate by Country')
plt.xlabel('Long Term Response Rate (%)')
plt.ylabel('Country')
legend_labels = ['Long Term Orientation Country', 'Short Term Orientation Country']
legend_colors = ['green', 'orange']
legend_handles = [plt.Rectangle((0,0),1,1, color=color) for color in legend_colors]
plt.legend(legend_handles, legend_labels, loc='upper left', bbox_to_anchor=(1, 1.1))
plt.grid(axis='x')
# Add win rate percentages on each bar
for i, v in enumerate(win_rate):
    plt.text(v + 0.5, i, f'{v:.2f}%', color='black', va='center')
plt.show()
# Out:
# Target_Nationality  Matching_Choice
# Albania             Long Term          45
#                     Short Term          5
# Armenia             Long Term          46
#                     Short Term          4
# Azerbaijan          Long Term          46
#                                        ..
# The United States   Short Term          5
# Turkey              Long Term          47
#                     Short Term          3
# Ukraine             Long Term          45
#                     Short Term          5
# Length: 72, dtype: int64

# %% [markdown]
# ## PDI

# %%
file_path = "/content/output_gemma_it_personas_power_distance.csv"
data = pd.read_csv(file_path)

# # Calculate the win rate (percentage of individualistic responses) for each country
# win_rate = (data[data['Matching_Choice'] == 'Masculine'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100
# win_rate_2 = (data[data['Matching_Choice'] == 'Feminine'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100
# Group by 'Target_Nationality' and 'Matching_Choice', then calculate the size of each group
grouped_data = data.groupby(['Target_Nationality', 'Matching_Choice']).size()
print(grouped_data)

# Pivot the table to make 'Matching_Choice' values as columns and fill missing values with 0
pivot_table = grouped_data.unstack(fill_value=0)

# Calculate the win rate (percentage of occurrences) for each country
win_rate = (pivot_table['Low Power Distance'] / (pivot_table['Low Power Distance'] + pivot_table['High Power Distance'])) * 100

# Sort the win rate values for better visualization
win_rate = win_rate.sort_values()

low_power_distance_countries = [
'The United States',
'Germany',
'Italy',
'The Netherlands',
'Hungary',
'Sweden',
'Israel',
'Denmark',
'Finland',
'South Africa', 'Iceland']
 # List of collectivist countries

# Define colors based on whether the target nationalities are individualistic or collectivist
colors = []
for country in win_rate.index:
    if country in low_power_distance_countries:
        colors.append('green')
    else:
        colors.append('orange')

# Plot the horizontal bar plot
plt.figure(figsize=(10, 8))
win_rate.plot(kind='barh', color=colors)
plt.title('Low Power Distance Index Response Rate by Country')
plt.xlabel('Low Power Distance Index Response Rate (%)')
plt.ylabel('Country')
legend_labels = ['Low Power Distance Index Country', 'High Power Distance Index Country']
legend_colors = ['green', 'orange']
legend_handles = [plt.Rectangle((0,0),1,1, color=color) for color in legend_colors]
plt.legend(legend_handles, legend_labels, loc='upper left', bbox_to_anchor=(1, 1.1))
plt.grid(axis='x')
# Add win rate percentages on each bar
for i, v in enumerate(win_rate):
    plt.text(v + 0.5, i, f'{v:.2f}%', color='black', va='center')
plt.show()
# Out:
# Target_Nationality  Matching_Choice
# Albania             High Power Distance    22
#                     Low Power Distance     28
# Armenia             High Power Distance    20
#                     Low Power Distance     30
# Azerbaijan          High Power Distance    23
#                                            ..
# The United States   Low Power Distance     27
# Turkey              High Power Distance    24
#                     Low Power Distance     26
# Ukraine             High Power Distance    18
#                     Low Power Distance     32
# Length: 72, dtype: int64

# %% [markdown]
# ## UNCERTAINTY

# %%
file_path = "/content/output_gemma_it_personas_uncertainty.csv"
data = pd.read_csv(file_path)

# # Calculate the win rate (percentage of individualistic responses) for each country
# win_rate = (data[data['Matching_Choice'] == 'Masculine'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100
# win_rate_2 = (data[data['Matching_Choice'] == 'Feminine'].groupby('Target_Nationality').size() / data.groupby('Target_Nationality').size()) * 100
# Group by 'Target_Nationality' and 'Matching_Choice', then calculate the size of each group
grouped_data = data.groupby(['Target_Nationality', 'Matching_Choice']).size()
print(grouped_data)

# Pivot the table to make 'Matching_Choice' values as columns and fill missing values with 0
pivot_table = grouped_data.unstack(fill_value=0)

# Calculate the win rate (percentage of occurrences) for each country
win_rate = (pivot_table['High Uncertainty Avoidance'] / (pivot_table['High Uncertainty Avoidance'] + pivot_table['Low Uncertainty Avoidance'])) * 100

# Sort the win rate values for better visualization
win_rate = win_rate.sort_values()

high_uncertainty_countries =  ['Germany', 'Italy', 'The Netherlands', 'Hungary', 'Israel', 'Finland', 'Russia',
                             'Japan', 'France', 'Turkey', 'Poland', 'Iran', 'Korea', 'Czechia', 'Ukraine', 'Greece',
                               'Romania', 'Thailand', 'Bulgaria', 'Kazakhstan', 'Armenia', 'Georgia', 'Albania',
                               'Azerbaijan', 'Belarus']
 # List of collectivist countries

# Define colors based on whether the target nationalities are individualistic or collectivist
colors = []
for country in win_rate.index:
    if country in high_uncertainty_countries:
        colors.append('green')
    else:
        colors.append('orange')

# Plot the horizontal bar plot
plt.figure(figsize=(10, 8))
win_rate.plot(kind='barh', color=colors)
plt.title('High Uncertainty Avoidance Response Rate by Country')
plt.xlabel('High Uncertainty Avoidance Response Rate (%)')
plt.ylabel('Country')
legend_labels = ['High Uncertainty Country', 'Low Uncertainty Country']
legend_colors = ['green', 'orange']
legend_handles = [plt.Rectangle((0,0),1,1, color=color) for color in legend_colors]
plt.legend(legend_handles, legend_labels, loc='upper left', bbox_to_anchor=(1, 1.1))
plt.grid(axis='x')
# Add win rate percentages on each bar
for i, v in enumerate(win_rate):
    plt.text(v + 0.5, i, f'{v:.2f}%', color='black', va='center')
plt.show()
# Out:
# Target_Nationality  Matching_Choice
# Albania             High Uncertainty Avoidance    17
#                     Low Uncertainty Avoidance     33
# Armenia             High Uncertainty Avoidance    19
#                     Low Uncertainty Avoidance     31
# Azerbaijan          High Uncertainty Avoidance    19
#                                                   ..
# The United States   Low Uncertainty Avoidance     34
# Turkey              High Uncertainty Avoidance    17
#                     Low Uncertainty Avoidance     33
# Ukraine             High Uncertainty Avoidance    16
#                     Low Uncertainty Avoidance     34
# Length: 72, dtype: int64

# %% [markdown]
# # % RESPONSE ANALYSIS

# %% [markdown]
# ## INDIVIDUALISM VS COLLECTIVISM

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_individualistic_collectivist.csv"
data = pd.read_csv(file_path)

# Calculate the counts of low and high power distance responses for each country
grouped_data = data.groupby(['Target_Nationality', 'Matching_Choice']).size().unstack(fill_value=0)

# Calculate the total number of responses for each country
grouped_data['Total'] = grouped_data.sum(axis=1)

# Calculate the proportion of low and high power distance responses for each country
grouped_data['Individualistic (%)'] = (grouped_data['Individualistic'] / grouped_data['Total']) * 100
grouped_data['Collectivist (%)'] = (grouped_data['Collectivist'] / grouped_data['Total']) * 100

# Sort the data by the proportion of low power distance responses for better visualization
grouped_data = grouped_data.sort_values(by='Individualistic (%)')

# Plot the stacked bar plot
plt.figure(figsize=(15, 8))  # Increase figure width for more space
grouped_data[['Individualistic (%)', 'Collectivist (%)']].plot(kind='barh', stacked=True, color=['green', 'orange'], width=0.4)  # Reduce bar width
plt.xlabel('Percentage (%)')
plt.ylabel('Country')
plt.title('Comparison of Individualist vs Collectivist Responses by Country')
plt.legend(title='Matching Choice', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='x')
plt.tick_params(axis='y', which='major', labelsize=8)
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %% [markdown]
# ## MAS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_mas.csv"
data = pd.read_csv(file_path)

# Calculate the counts of low and high power distance responses for each country
grouped_data = data.groupby(['Target_Nationality', 'Matching_Choice']).size().unstack(fill_value=0)

# Calculate the total number of responses for each country
grouped_data['Total'] = grouped_data.sum(axis=1)

# Calculate the proportion of low and high power distance responses for each country
grouped_data['Masculine (%)'] = (grouped_data['Masculine'] / grouped_data['Total']) * 100
grouped_data['Feminine (%)'] = (grouped_data['Feminine'] / grouped_data['Total']) * 100

# Sort the data by the proportion of low power distance responses for better visualization
grouped_data = grouped_data.sort_values(by='Feminine (%)')

# Plot the stacked bar plot
plt.figure(figsize=(15, 8))  # Increase figure width for more space
grouped_data[['Masculine (%)', 'Feminine (%)']].plot(kind='barh', stacked=True, color=['green', 'orange'], width=0.4)  # Reduce bar width
plt.xlabel('Percentage (%)')
plt.ylabel('Country')
plt.title('Comparison of High MAS vs Low MAS Responses by Country')
plt.legend(title='Matching Choice', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='x')
plt.tick_params(axis='y', which='major', labelsize=8)
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %% [markdown]
# ## ORIENTATION

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_orientation.csv"
data = pd.read_csv(file_path)

# Calculate the counts of low and high power distance responses for each country
grouped_data = data.groupby(['Target_Nationality', 'Matching_Choice']).size().unstack(fill_value=0)

# Calculate the total number of responses for each country
grouped_data['Total'] = grouped_data.sum(axis=1)

# Calculate the proportion of low and high power distance responses for each country
grouped_data['Long Term Orientation (%)'] = (grouped_data['Long Term'] / grouped_data['Total']) * 100
grouped_data['Short Term Orientation (%)'] = (grouped_data['Short Term'] / grouped_data['Total']) * 100

# Sort the data by the proportion of low power distance responses for better visualization
grouped_data = grouped_data.sort_values(by='Long Term Orientation (%)')

# Plot the stacked bar plot
plt.figure(figsize=(15, 8))  # Increase figure width for more space
grouped_data[['Long Term Orientation (%)', 'Short Term Orientation (%)']].plot(kind='barh', stacked=True, color=['green', 'orange'], width=0.4)  # Reduce bar width
plt.xlabel('Percentage (%)')
plt.ylabel('Country')
plt.title('Comparison of Long Term Orientation vs Short Term Orientation Responses by Country')
plt.legend(title='Matching Choice', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='x')
plt.tick_params(axis='y', which='major', labelsize=8)
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %% [markdown]
# ## PDI

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_power_distance.csv"
data = pd.read_csv(file_path)

# Calculate the counts of low and high power distance responses for each country
grouped_data = data.groupby(['Target_Nationality', 'Matching_Choice']).size().unstack(fill_value=0)

# Calculate the total number of responses for each country
grouped_data['Total'] = grouped_data.sum(axis=1)

# Calculate the proportion of low and high power distance responses for each country
grouped_data['High PDI (%)'] = (grouped_data['High Power Distance'] / grouped_data['Total']) * 100
grouped_data['Low PDI (%)'] = (grouped_data['Low Power Distance'] / grouped_data['Total']) * 100

# Sort the data by the proportion of low power distance responses for better visualization
grouped_data = grouped_data.sort_values(by='High PDI (%)')

# Plot the stacked bar plot
plt.figure(figsize=(15, 8))  # Increase figure width for more space
grouped_data[['High PDI (%)', 'Low PDI (%)']].plot(kind='barh', stacked=True, color=['green', 'orange'], width=0.4)  # Reduce bar width
plt.xlabel('Percentage (%)')
plt.ylabel('Country')
plt.title('Comparison of High PDI vs Low PDI Responses by Country')
plt.legend(title='Matching Choice', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='x')
plt.tick_params(axis='y', which='major', labelsize=8)
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %% [markdown]
# ## UNCERTAINTY

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_uncertainty.csv"
data = pd.read_csv(file_path)

# Calculate the counts of low and high power distance responses for each country
grouped_data = data.groupby(['Target_Nationality', 'Matching_Choice']).size().unstack(fill_value=0)

# Calculate the total number of responses for each country
grouped_data['Total'] = grouped_data.sum(axis=1)

# Calculate the proportion of low and high power distance responses for each country
grouped_data['High Uncertainty Avoidance (%)'] = (grouped_data['High Uncertainty Avoidance'] / grouped_data['Total']) * 100
grouped_data['Low Uncertainty Avoidance (%)'] = (grouped_data['Low Uncertainty Avoidance'] / grouped_data['Total']) * 100

# Sort the data by the proportion of low power distance responses for better visualization
grouped_data = grouped_data.sort_values(by='Low Uncertainty Avoidance (%)')

# Plot the stacked bar plot
plt.figure(figsize=(15, 8))  # Increase figure width for more space
grouped_data[['High Uncertainty Avoidance (%)', 'Low Uncertainty Avoidance (%)']].plot(kind='barh', stacked=True, color=['green', 'orange'], width=0.4)  # Reduce bar width
plt.xlabel('Percentage (%)')
plt.ylabel('Country')
plt.title('Comparison of High Uncertainty Avoidance vs Low Uncertainty Avoidance Responses by Country')
plt.legend(title='Matching Choice', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='x')
plt.tick_params(axis='y', which='major', labelsize=8)
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %% [markdown]
# # HISTOGRAM DISTRIBUTIONS

# %% [markdown]
# ## INDIVIDUALISM VS COLLECTIVISM

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_individualistic_collectivist.csv"
data = pd.read_csv(file_path)

# Separate the data into Masculine and Feminine responses
masculine_data = data[data['Matching_Choice'] == 'Individualistic']
feminine_data = data[data['Matching_Choice'] == 'Collectivist']

# Get unique country names and their counts
unique_countries = data['Target_Nationality'].unique()
num_countries = len(unique_countries)

# Create evenly spaced bins for each country
bins = np.arange(num_countries + 0.5) - 0.5

# Plot histograms for Masculine and Feminine responses
plt.figure(figsize=(12, 6))

# Histogram for Masculine responses
plt.hist(masculine_data['Target_Nationality'], bins=bins, alpha=0.7, color='green', label='Individualistic')

# Histogram for Feminine responses
plt.hist(feminine_data['Target_Nationality'], bins=bins, alpha=0.7, color='orange', label='Collectivist')

plt.xlabel('Country')
plt.ylabel('Frequency')
plt.title('Distribution of Individualistic and Collectivist Responses by Country')
plt.xticks(np.arange(num_countries), unique_countries, rotation=45)  # Set custom x-axis ticks
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## MAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_mas.csv"
data = pd.read_csv(file_path)

# Separate the data into Masculine and Feminine responses
masculine_data = data[data['Matching_Choice'] == 'Masculine']
feminine_data = data[data['Matching_Choice'] == 'Feminine']

# Get unique country names and their counts
unique_countries = data['Target_Nationality'].unique()
num_countries = len(unique_countries)

# Create evenly spaced bins for each country
bins = np.arange(num_countries + 0.5) - 0.5

# Plot histograms for Masculine and Feminine responses
plt.figure(figsize=(12, 6))

# Histogram for Masculine responses
plt.hist(masculine_data['Target_Nationality'], bins=bins, alpha=0.7, color='green', label='Masculine')

# Histogram for Feminine responses
plt.hist(feminine_data['Target_Nationality'], bins=bins, alpha=0.7, color='orange', label='Feminine')

plt.xlabel('Country')
plt.ylabel('Frequency')
plt.title('Distribution of Masculine and Feminine Responses by Country')
plt.xticks(np.arange(num_countries), unique_countries, rotation=45)  # Set custom x-axis ticks
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ORIENTATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_orientation.csv"
data = pd.read_csv(file_path)

# Separate the data into Masculine and Feminine responses
masculine_data = data[data['Matching_Choice'] == 'Long Term']
feminine_data = data[data['Matching_Choice'] == 'Short Term']

# Get unique country names and their counts
unique_countries = data['Target_Nationality'].unique()
num_countries = len(unique_countries)

# Create evenly spaced bins for each country
bins = np.arange(num_countries + 0.5) - 0.5

# Plot histograms for Masculine and Feminine responses
plt.figure(figsize=(12, 6))

# Histogram for Masculine responses
plt.hist(masculine_data['Target_Nationality'], bins=bins, alpha=0.7, color='green', label='Long Term')

# Histogram for Feminine responses
plt.hist(feminine_data['Target_Nationality'], bins=bins, alpha=0.7, color='orange', label='Short Term')

plt.xlabel('Country')
plt.ylabel('Frequency')
plt.title('Distribution of Long Term and Short Term Responses by Country')
plt.xticks(np.arange(num_countries), unique_countries, rotation=45)  # Set custom x-axis ticks
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # DENSITY CURVES

# %% [markdown]
# ## MAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_mas.csv"
data = pd.read_csv(file_path)

# Separate the data into Masculine and Feminine responses
masculine_data = data[data['Matching_Choice'] == 'Masculine']
feminine_data = data[data['Matching_Choice'] == 'Feminine']

# Calculate frequencies of responses for each nationality
masculine_counts = masculine_data['Target_Nationality'].value_counts().sort_index()
feminine_counts = feminine_data['Target_Nationality'].value_counts().sort_index()

# Create a DataFrame with these counts
freq_data = pd.DataFrame({
    'Masculine': masculine_counts,
    'Feminine': feminine_counts
}).fillna(0)  # Fill NaNs with 0

# Plot KDEs for Masculine and Feminine responses
plt.figure(figsize=(12, 6))

sns.kdeplot(freq_data['Masculine'], color='green', label='Masculine', bw_adjust=0.5)
sns.kdeplot(freq_data['Feminine'], color='orange', label='Feminine', bw_adjust=0.5)

plt.xlabel('Frequency of Responses')
plt.ylabel('Density')
plt.title('Density of Masculine and Feminine Responses by Frequency')
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_mas.csv"
data = pd.read_csv(file_path)

# Separate the data into Masculine and Feminine responses
masculine_data = data[data['Matching_Choice'] == 'Masculine']
feminine_data = data[data['Matching_Choice'] == 'Feminine']

# Calculate frequencies of responses for each nationality
masculine_counts = masculine_data['Target_Nationality'].value_counts()
feminine_counts = feminine_data['Target_Nationality'].value_counts()

# Create a DataFrame with these counts
freq_data = pd.DataFrame({
    'Masculine': masculine_counts,
    'Feminine': feminine_counts
}).fillna(0)  # Fill NaNs with 0

# Calculate total responses for each country
freq_data['Total'] = freq_data['Masculine'] + freq_data['Feminine']

# List of high MAS countries
high_mas_countries = ['The United States', 'Germany', 'Italy', 'Hungary', 'South Africa', 'Japan',
                      'Poland', 'Czechia', 'Greece', 'Georgia', 'Albania', 'India']

# Determine the expectation (Masculine or Feminine) for each country based on high MAS list
freq_data['Expectation'] = np.where(freq_data.index.isin(high_mas_countries), 'Masculine', 'Feminine')

# Separate the countries based on expectation
masculine_expected = freq_data[freq_data['Expectation'] == 'Masculine']['Total']
feminine_expected = freq_data[freq_data['Expectation'] == 'Feminine']['Total']

# Plot histograms for countries expected to be masculine and feminine
plt.figure(figsize=(12, 6))

sns.histplot(masculine_expected, color='green', label='Masculine Expected', kde=True, bins=20)
sns.histplot(feminine_expected, color='orange', label='Feminine Expected', kde=True, bins=20)

plt.xlabel('Total Responses')
plt.ylabel('Count of Countries')
plt.title('Distribution of Countries by Expected Masculine or Feminine Responses')
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_mas.csv"
data = pd.read_csv(file_path)

# Define masculine countries
masculine_countries = ['The United States', 'Germany', 'Italy', 'Hungary', 'South Africa', 'Japan', 'Poland', 'Czechia',
                          'Greece', 'Georgia', 'Albania', 'India']

# Encode "Matching_Choice" (replace with label encoding or one-hot encoding for more complex datasets)
data['Matching_Choice_code'] = data['Matching_Choice'].map({'Masculine': 1, 'Feminine': 0})

# Filter data for masculine countries (or calculate average score for all countries)
if len(masculine_countries) > 0:
  masculine_data = data[data['Target_Nationality'].isin(masculine_countries)]
  masculinity_score = masculine_data['Matching_Choice_code'].mean()
else:
  # Calculate average score for all countries (assuming all countries data is available)
  masculinity_score = data['Matching_Choice_code'].mean()

# All other countries are considered feminine (can be adjusted)
feminine_countries = data['Target_Nationality'].unique()
feminine_countries = [country for country in feminine_countries if country not in masculine_countries]

# Filter data for feminine countries (optional, data already filtered for masculine countries)
# feminine_data = data[data['Target_Nationality'].isin(feminine_countries)]

# Create histograms
plt.figure(figsize=(12, 6))
plt.hist([masculinity_score], bins=10, alpha=0.7, label='Masculine')
plt.hist(data[data['Target_Nationality'].isin(feminine_countries)]['Matching_Choice_code'].mean(), bins=10, alpha=0.7, label='Feminine (All Others)')  # Average score for remaining countries

plt.xlabel('Masculinity Score (Encoded Matching_Choice)')
plt.ylabel('Number of Countries')
plt.title('Distribution of Masculinity Score for Predefined Masculine Countries vs. Others')
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_mas.csv"
data = pd.read_csv(file_path)

# Ensure the 'Matching_Choice' column is numeric
data['Matching_Choice_Numerical'] = pd.to_numeric(data['Matching_Choice'], errors='coerce')

# Define the lists of countries expected to be masculine or feminine
masculine_countries = ['The United States', 'Germany', 'Italy', 'Hungary', 'South Africa', 'Japan', 'Poland', 'Czechia',
                       'Greece', 'Georgia', 'Albania', 'India']
feminine_countries = [country for country in data['Target_Nationality'].unique() if country not in masculine_countries]

# Filter the data based on the expected masculinity or femininity
masculine_data = data[data['Target_Nationality'].isin(masculine_countries)]
feminine_data = data[~data['Target_Nationality'].isin(masculine_countries)]

# Assuming 'Response_Type' column exists with values 'Masculine' and 'Feminine'
# Split the data into different groups based on response type and country type
masculine_responses_given_masculine_data = masculine_data[masculine_data['Matching_Choice'] == 'Masculine']
feminine_responses_given_masculine_data = masculine_data[masculine_data['Matching_Choice'] == 'Feminine']
masculine_responses_given_feminine_data = feminine_data[feminine_data['Matching_Choice'] == 'Masculine']
feminine_responses_given_feminine_data = feminine_data[feminine_data['Matching_Choice'] == 'Feminine']

# Plot the KDEs
plt.figure(figsize=(12, 8))

sns.kdeplot(masculine_responses_given_masculine_data['Matching_Choice_Numerical'].dropna(), label='Masculine Responses Given Masculine Data', color='blue')
sns.kdeplot(feminine_responses_given_masculine_data['Matching_Choice_Numerical'].dropna(), label='Feminine Responses Given Masculine Data', color='green')
sns.kdeplot(masculine_responses_given_feminine_data['Matching_Choice_Numerical'].dropna(), label='Masculine Responses Given Feminine Data', color='red')
sns.kdeplot(feminine_responses_given_feminine_data['Matching_Choice_Numerical'].dropna(), label='Feminine Responses Given Feminine Data', color='purple')

plt.title('Density of Responses by Response Type and Country Type')
plt.xlabel('Matching Choice')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Individualism vs Collectivism

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_individualistic_collectivist.csv"
data = pd.read_csv(file_path)

# Separate the data into Masculine and Feminine responses
masculine_data = data[data['Matching_Choice'] == 'Individualistic']
feminine_data = data[data['Matching_Choice'] == 'Collectivist']

# Calculate frequencies of responses for each nationality
masculine_counts = masculine_data['Target_Nationality'].value_counts().sort_index()
feminine_counts = feminine_data['Target_Nationality'].value_counts().sort_index()

# Create a DataFrame with these counts
freq_data = pd.DataFrame({
    'Individualistic': masculine_counts,
    'Collectivist': feminine_counts
}).fillna(0)  # Fill NaNs with 0

# Plot KDEs for Masculine and Feminine responses
plt.figure(figsize=(12, 6))

sns.kdeplot(freq_data['Individualistic'], color='green', label='Individualistic', bw_adjust=0.5)
sns.kdeplot(freq_data['Collectivist'], color='orange', label='Collectivist', bw_adjust=0.5)

plt.xlabel('Frequency of Responses')
plt.ylabel('Density')
plt.title('Density of Individualistic and Collectivist Responses by Frequency')
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ORIENTATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the data from the input file
file_path = "/content/output_gemma_it_personas_orientation.csv"
data = pd.read_csv(file_path)

# Separate the data into Masculine and Feminine responses
masculine_data = data[data['Matching_Choice'] == 'Long Term']
feminine_data = data[data['Matching_Choice'] == 'Short Term']

# Calculate frequencies of responses for each nationality
masculine_counts = masculine_data['Target_Nationality'].value_counts().sort_index()
feminine_counts = feminine_data['Target_Nationality'].value_counts().sort_index()

# Create a DataFrame with these counts
freq_data = pd.DataFrame({
    'Long Term': masculine_counts,
    'Short Term': feminine_counts
}).fillna(0)  # Fill NaNs with 0

# Plot KDEs for Masculine and Feminine responses
plt.figure(figsize=(12, 6))

sns.kdeplot(freq_data['Long Term'], color='green', label='Long Term', bw_adjust=0.5)
sns.kdeplot(freq_data['Short Term'], color='orange', label='Short Term', bw_adjust=0.5)

plt.xlabel('Frequency of Responses')
plt.ylabel('Density')
plt.title('Density of Long Term and Short Term Orientation Responses by Frequency')
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # DENSITY CURVES TO SHOW DIFFERENTIATION OF VALUES

# %% [markdown]
# ## INDIVIDUALISM VS COLLECTIVISM

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the data from the input file
file_path = "/content/output_gemma_it_personas_individualistic_collectivist.csv"
# file_path = "julia/output_openai_personas_individualistic_collectivist (2).csv"
data = pd.read_csv(file_path)
# collectivist_country_data['Matching_Choice'].value_counts()
# Individualistic    2562
# Collectivist       2357
# Inconclusive         81
# throw out inconclusive
data = data[data['Matching_Choice'] != 'Inconclusive']
# make Individualistic_Response a boolean
data['Individualistic_Response'] = data['Matching_Choice'] == 'Individualistic'

# aggregate by Target_Nationality and take the mean of Individualistic_Response
data = data.groupby('Target_Nationality').agg({'Individualistic_Response': 'mean'}).reset_index()

# Define lists of collectivist and individualistic countries
collectivist_countries = ['Russia', 'China', 'Indonesia', 'Turkey', 'Poland', 'Iran',
                          'Romania', 'Thailand', 'Bulgaria', 'Kazakhstan', 'Armenia',
                          'Georgia', 'Albania', 'Azerbaijan', 'Malaysia', 'Mongolia',
                          'Belarus', 'India', 'South Africa', 'Sri Lanka']

data['collectivist'] = data['Target_Nationality'].isin(collectivist_countries)


# Calculate frequencies of responses for each nationality
collectivist_country_perc = data[data['collectivist']]['Individualistic_Response']
individualistic_country_counts = data[~data['collectivist']]['Individualistic_Response']

# make KDE
plt.figure(figsize=(12, 6))
sns.kdeplot(collectivist_country_perc, color='green', label='Collectivist Countries', bw_adjust=0.5)
sns.kdeplot(individualistic_country_counts, color='orange', label='Individualistic Countries', bw_adjust=0.5)
plt.xlabel('Average % of Individualistic Responses (Country)', fontsize=25)
plt.ylabel('Density', fontsize=25)
plt.title('Gemma, Personas - Density of Responses by Frequency\n for Collectivist and Individualistic Countries', fontsize=25)
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score
import numpy as np

X = np.concatenate((collectivist_country_perc, individualistic_country_counts)).reshape(-1, 1)
y = np.concatenate((np.zeros(len(collectivist_country_perc)), np.ones(len(individualistic_country_counts))))
# sweep a dense linspace of thresholds
threshs = np.linspace(0, 1, 100)
# calculate the accuracy for each threshold
best_acc = max(
    np.max([accuracy_score(y, X.ravel() > thresh) for thresh in threshs]),
    np.max([accuracy_score(y, X.ravel() < thresh) for thresh in threshs])
)
# plt.plot(threshs, accuracies)
print(best_acc)
# Out:
# 0.6388888888888888

# %% [markdown]
# ## PDI

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the data from the input file
file_path = "/content/output_gemma_it_personas_power_distance.csv"
# file_path = "julia/output_openai_personas_individualistic_collectivist (2).csv"
data = pd.read_csv(file_path)
# collectivist_country_data['Matching_Choice'].value_counts()
# Individualistic    2562
# Collectivist       2357
# Inconclusive         81
# throw out inconclusive
data = data[data['Matching_Choice'] != 'Inconclusive']
# make Individualistic_Response a boolean
data['Low_Power_Distance_Index_Response'] = data['Matching_Choice'] == 'Low Power Distance'

# aggregate by Target_Nationality and take the mean of Individualistic_Response
data = data.groupby('Target_Nationality').agg({'Low_Power_Distance_Index_Response': 'mean'}).reset_index()

# Define lists of collectivist and individualistic countries
low_power_distance_countries = [
'The United States',
'Germany',
'Italy',
'The Netherlands',
'Hungary',
'Sweden',
'Israel',
'Denmark',
'Finland',
'South Africa', 'Iceland']

data['low_pdi'] = data['Target_Nationality'].isin(low_power_distance_countries)


# Calculate frequencies of responses for each nationality
collectivist_country_perc = data[data['low_pdi']]['Low_Power_Distance_Index_Response']
individualistic_country_counts = data[~data['low_pdi']]['Low_Power_Distance_Index_Response']

# make KDE
plt.figure(figsize=(12, 6))
sns.kdeplot(collectivist_country_perc, color='green', label='Low PDI Countries', bw_adjust=0.5)
sns.kdeplot(individualistic_country_counts, color='orange', label='High PDI Countries', bw_adjust=0.5)
plt.xlabel('Average % of Low PDI Responses (Country)', fontsize=25)
plt.ylabel('Density', fontsize=25)
plt.title('Gemma, Personas - Density of Responses by Frequency\n for Low PDI and High PDI Countries', fontsize=25)
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score
import numpy as np

X = np.concatenate((collectivist_country_perc, individualistic_country_counts)).reshape(-1, 1)
y = np.concatenate((np.zeros(len(collectivist_country_perc)), np.ones(len(individualistic_country_counts))))
# sweep a dense linspace of thresholds
threshs = np.linspace(0, 1, 100)
# calculate the accuracy for each threshold
best_acc = max(
    np.max([accuracy_score(y, X.ravel() > thresh) for thresh in threshs]),
    np.max([accuracy_score(y, X.ravel() < thresh) for thresh in threshs])
)
# plt.plot(threshs, accuracies)
print(best_acc)
# Out:
# 0.7777777777777778

# %% [markdown]
# ## ORIENTATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the data from the input file
file_path = "/content/output_gemma_it_personas_orientation.csv"
# file_path = "julia/output_openai_personas_individualistic_collectivist (2).csv"
data = pd.read_csv(file_path)
# collectivist_country_data['Matching_Choice'].value_counts()
# Individualistic    2562
# Collectivist       2357
# Inconclusive         81
# throw out inconclusive
data = data[data['Matching_Choice'] != 'Inconclusive']
# make Individualistic_Response a boolean
data['Long_Term_Orientation_Response'] = data['Matching_Choice'] == 'Long Term'

# aggregate by Target_Nationality and take the mean of Individualistic_Response
data = data.groupby('Target_Nationality').agg({'Long_Term_Orientation_Response': 'mean'}).reset_index()

# Define lists of collectivist and individualistic countries
high_long_term_countries =  ['Germany', 'Russia', 'Japan', 'France', 'China', 'The Netherlands', 'South Korea',
                             'Czech Republic', 'Ukraine', 'Greece', 'Sweden', 'Denmark', 'Thailand', 'Finland',
                             'Bulgaria', 'Kazakhstan', 'Albania', 'Azerbaijan', 'Belarus', 'India', 'Iceland']

data['long_term'] = data['Target_Nationality'].isin(high_long_term_countries)


# Calculate frequencies of responses for each nationality
collectivist_country_perc = data[data['long_term']]['Long_Term_Orientation_Response']
individualistic_country_counts = data[~data['long_term']]['Long_Term_Orientation_Response']

# make KDE
plt.figure(figsize=(12, 6))
sns.kdeplot(collectivist_country_perc, color='green', label='Long Term Orientation Countries', bw_adjust=0.5)
sns.kdeplot(individualistic_country_counts, color='orange', label='Short Term Orientation Countries', bw_adjust=0.5)
plt.xlabel('Average % of Long Term Orientation Responses (Country)', fontsize=25)
plt.ylabel('Density', fontsize=25)
plt.title('Gemma, Personas - Density of Responses by Frequency\n for Long Term and Short Term Orientation Countries', fontsize=25)
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score
import numpy as np

X = np.concatenate((collectivist_country_perc, individualistic_country_counts)).reshape(-1, 1)
y = np.concatenate((np.zeros(len(collectivist_country_perc)), np.ones(len(individualistic_country_counts))))
# sweep a dense linspace of thresholds
threshs = np.linspace(0, 1, 100)
# calculate the accuracy for each threshold
best_acc = max(
    np.max([accuracy_score(y, X.ravel() > thresh) for thresh in threshs]),
    np.max([accuracy_score(y, X.ravel() < thresh) for thresh in threshs])
)
# plt.plot(threshs, accuracies)
print(best_acc)
# Out:
# 0.6111111111111112

# %% [markdown]
# ## UNCERTAINTY

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the data from the input file
file_path = "/content/output_gemma_it_personas_uncertainty.csv"
# file_path = "julia/output_openai_personas_individualistic_collectivist (2).csv"
data = pd.read_csv(file_path)
# collectivist_country_data['Matching_Choice'].value_counts()
# Individualistic    2562
# Collectivist       2357
# Inconclusive         81
# throw out inconclusive
data = data[data['Matching_Choice'] != 'Inconclusive']
# make Individualistic_Response a boolean
data['High_Uncertainty_Avoidance_Response'] = data['Matching_Choice'] == 'High Uncertainty Avoidance'

# aggregate by Target_Nationality and take the mean of Individualistic_Response
data = data.groupby('Target_Nationality').agg({'High_Uncertainty_Avoidance_Response': 'mean'}).reset_index()

# Define lists of collectivist and individualistic countries
high_uncertainty_countries =  ['Germany', 'Italy', 'The Netherlands', 'Hungary', 'Israel', 'Finland', 'Russia',
                             'Japan', 'France', 'Turkey', 'Poland', 'Iran', 'Korea', 'Czechia', 'Ukraine', 'Greece',
                               'Romania', 'Thailand', 'Bulgaria', 'Kazakhstan', 'Armenia', 'Georgia', 'Albania',
                               'Azerbaijan', 'Belarus']

data['high_uncertainty'] = data['Target_Nationality'].isin(high_uncertainty_countries)


# Calculate frequencies of responses for each nationality
collectivist_country_perc = data[data['high_uncertainty']]['High_Uncertainty_Avoidance_Response']
individualistic_country_counts = data[~data['high_uncertainty']]['High_Uncertainty_Avoidance_Response']

# make KDE
plt.figure(figsize=(12, 6))
sns.kdeplot(collectivist_country_perc, color='green', label='High Uncertainty Avoidance Countries', bw_adjust=0.5)
sns.kdeplot(individualistic_country_counts, color='orange', label='Low Uncertainty Avoidance Countries', bw_adjust=0.5)
plt.xlabel('Average % of High Uncertainty Avoidance Responses (Country)', fontsize=25)
plt.ylabel('Density', fontsize=25)
plt.title('Gemma, Personas - Density of Responses by Frequency\n for High and Low Uncertainty Avoidance Countries', fontsize=25)
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score
import numpy as np

X = np.concatenate((collectivist_country_perc, individualistic_country_counts)).reshape(-1, 1)
y = np.concatenate((np.zeros(len(collectivist_country_perc)), np.ones(len(individualistic_country_counts))))
# sweep a dense linspace of thresholds
threshs = np.linspace(0, 1, 100)
# calculate the accuracy for each threshold
best_acc = max(
    np.max([accuracy_score(y, X.ravel() > thresh) for thresh in threshs]),
    np.max([accuracy_score(y, X.ravel() < thresh) for thresh in threshs])
)
# plt.plot(threshs, accuracies)
print(best_acc)
# Out:
# 0.6666666666666666

# %% [markdown]
# ## MAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the data from the input file
file_path = "/content/output_gemma_it_personas_mas.csv"
# file_path = "julia/output_openai_personas_individualistic_collectivist (2).csv"
data = pd.read_csv(file_path)
# collectivist_country_data['Matching_Choice'].value_counts()
# Individualistic    2562
# Collectivist       2357
# Inconclusive         81
# throw out inconclusive
data = data[data['Matching_Choice'] != 'Inconclusive']
# make Individualistic_Response a boolean
data['High_MAS'] = data['Matching_Choice'] == 'Masculine'

# aggregate by Target_Nationality and take the mean of Individualistic_Response
data = data.groupby('Target_Nationality').agg({'High_MAS': 'mean'}).reset_index()

# Define lists of collectivist and individualistic countries
high_mas_countries = ['The United States', 'Germany', 'Italy', 'Hungary', 'South Africa', 'Japan', 'Poland', 'Czechia',
                          'Greece', 'Georgia', 'Albania', 'India']

data['high_mas'] = data['Target_Nationality'].isin(high_mas_countries)


# Calculate frequencies of responses for each nationality
collectivist_country_perc = data[data['high_mas']]['High_MAS']
individualistic_country_counts = data[~data['high_mas']]['High_MAS']

# make KDE
plt.figure(figsize=(12, 6))
sns.kdeplot(collectivist_country_perc, color='green', label='High MAS Countries', bw_adjust=0.5)
sns.kdeplot(individualistic_country_counts, color='orange', label='Low MAS Countries', bw_adjust=0.5)
plt.xlabel('Average % of High MAS Responses (Country)', fontsize=25)
plt.ylabel('Density', fontsize=25)
plt.title('Gemma, Personas - Density of Responses by Frequency\n for High and Low MAS Countries', fontsize=25)
plt.legend()
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score
import numpy as np

X = np.concatenate((collectivist_country_perc, individualistic_country_counts)).reshape(-1, 1)
y = np.concatenate((np.zeros(len(collectivist_country_perc)), np.ones(len(individualistic_country_counts))))
# sweep a dense linspace of thresholds
threshs = np.linspace(0, 1, 100)
# calculate the accuracy for each threshold
best_acc = max(
    np.max([accuracy_score(y, X.ravel() > thresh) for thresh in threshs]),
    np.max([accuracy_score(y, X.ravel() < thresh) for thresh in threshs])
)
# plt.plot(threshs, accuracies)
print(best_acc)
# Out:
# 0.7222222222222222

# %% [markdown]
# # COMPARISON BY COUNTRY'S EXPECTED VALUES

# %% [markdown]
# ## INDIVIDUALISM VS COLLECTIVISM

# %%
file_path = "/content/output_gemma_it_personas_individualistic_collectivist.csv"
data = pd.read_csv(file_path)

individualistic_true_data = data[data['Individualistic'] == True]
individualistic_false_data = data[data['Individualistic'] == False]

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for True
grouped_data_true = individualistic_true_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for False
grouped_data_false = individualistic_false_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Plot the data for Individualistic = True
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

grouped_data_true.plot(kind='barh', stacked=True, ax=axes[0])
axes[0].set_ylabel('Country')
axes[0].set_xlabel('Count')
axes[0].set_title('Individualistic = True')
axes[0].legend(title='Adheres to Value')

# Plot the data for Individualistic = False
grouped_data_false.plot(kind='barh', stacked=True, ax=axes[1])
axes[1].set_ylabel('Country')
axes[1].set_xlabel('Count')
axes[1].set_title('Individualistic = False')
axes[1].legend(title='Adheres to Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## MAS

# %%
file_path = "/content/output_gemma_it_personas_mas.csv"
data = pd.read_csv(file_path)

mas_high_data = data[data['Masculine'] == True]
mas_low_data = data[data['Masculine'] == False]

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for True
grouped_data_true = mas_high_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for False
grouped_data_false = mas_low_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Plot the data for Individualistic = True
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

grouped_data_true.plot(kind='barh', stacked=True, ax=axes[0])
axes[0].set_ylabel('Country')
axes[0].set_xlabel('Count')
axes[0].set_title('High MAS Countries')
axes[0].legend(title='Adheres to Value')

# Plot the data for Individualistic = False
grouped_data_false.plot(kind='barh', stacked=True, ax=axes[1])
axes[1].set_ylabel('Country')
axes[1].set_xlabel('Count')
axes[1].set_title('Low MAS Countries')
axes[1].legend(title='Adheres to Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ORIENTATION

# %%
file_path = "/content/output_gemma_it_personas_orientation.csv"
data = pd.read_csv(file_path)

individualistic_true_data = data[data['Long_Term_Orientation'] == True]
individualistic_false_data = data[data['Long_Term_Orientation'] == False]

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for True
grouped_data_true = individualistic_true_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for False
grouped_data_false = individualistic_false_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Plot the data for Individualistic = True
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

grouped_data_true.plot(kind='barh', stacked=True, ax=axes[0])
axes[0].set_ylabel('Country')
axes[0].set_xlabel('Count')
axes[0].set_title('Long Term Orientation')
axes[0].legend(title='Adheres to Value')

# Plot the data for Individualistic = False
grouped_data_false.plot(kind='barh', stacked=True, ax=axes[1])
axes[1].set_ylabel('Country')
axes[1].set_xlabel('Count')
axes[1].set_title('Short Term Orientation')
axes[1].legend(title='Adheres to Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# # COMPARISON BY COUNTRY'S RESOURCE LEVEL

# %% [markdown]
# ## INDIVIDUALISM VS COLLECTIVISM

# %%
# Separate the data into three groups based on the 'Resource' column
file_path = "/content/output_gemma_it_personas_individualistic_collectivist.csv"
data = pd.read_csv(file_path)
high_resource_data = data[data['Resource_Level'] == 'High']
mid_resource_data = data[data['Resource_Level'] == 'Mid']
low_resource_data = data[data['Resource_Level'] == 'Low']

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for High resource
grouped_data_high = high_resource_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for Mid resource
grouped_data_mid = mid_resource_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for Low resource
grouped_data_low = low_resource_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Plot the data for High resource
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

grouped_data_high.plot(kind='barh', stacked=True, ax=axes[0])
axes[0].set_xlabel('Count')
axes[0].set_ylabel('Country')
axes[0].set_title('Resource = High')
axes[0].legend(title='Adheres to Value')

# Plot the data for Mid resource
grouped_data_mid.plot(kind='barh', stacked=True, ax=axes[1])
axes[1].set_xlabel('Count')
axes[1].set_ylabel('Country')
axes[1].set_title('Resource = Mid')
axes[1].legend(title='Adheres to Value')

# Plot the data for Low resource
grouped_data_low.plot(kind='barh', stacked=True, ax=axes[2])
axes[2].set_xlabel('Count')
axes[2].set_ylabel('Country')
axes[2].set_title('Resource = Low')
axes[2].legend(title='Adheres to Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## MAS

# %%
file_path = '/content/output_gemma_it_personas_mas.csv'
data = pd.read_csv(file_path)
# Separate the data into three groups based on the 'Resource' column
high_resource_data = data[data['Resource_Level'] == 'High']
mid_resource_data = data[data['Resource_Level'] == 'Mid']
low_resource_data = data[data['Resource_Level'] == 'Low']

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for High resource
grouped_data_high = high_resource_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for Mid resource
grouped_data_mid = mid_resource_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for Low resource
grouped_data_low = low_resource_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Plot the data for High resource
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

grouped_data_high.plot(kind='barh', stacked=True, ax=axes[0])
axes[0].set_xlabel('Adheres to Value')
axes[0].set_ylabel('Count')
axes[0].set_title('Resource = High')
axes[0].legend(title='Adheres to Value')

# Plot the data for Mid resource
grouped_data_mid.plot(kind='barh', stacked=True, ax=axes[1])
axes[1].set_xlabel('Adheres to Value')
axes[1].set_ylabel('Count')
axes[1].set_title('Resource = Mid')
axes[1].legend(title='Adheres to Value')

# Plot the data for Low resource
grouped_data_low.plot(kind='barh', stacked=True, ax=axes[2])
axes[2].set_xlabel('Adheres to Value')
axes[2].set_ylabel('Count')
axes[2].set_title('Resource = Low')
axes[2].legend(title='Adheres to Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ORIENTATION

# %%
file_path = "/content/output_gemma_it_personas_orientation.csv"
data = pd.read_csv(file_path)
# Separate the data into three groups based on the 'Resource' column
high_resource_data = data[data['Resource_Level'] == 'High']
mid_resource_data = data[data['Resource_Level'] == 'Mid']
low_resource_data = data[data['Resource_Level'] == 'Low']

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for High resource
grouped_data_high = high_resource_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for Mid resource
grouped_data_mid = mid_resource_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Group the data by 'Target_Nationality' and 'Adheres to Value', and count the occurrences for Low resource
grouped_data_low = low_resource_data.groupby(['Target_Nationality', 'Adheres_to_Value']).size().unstack().fillna(0)

# Plot the data for High resource
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

grouped_data_high.plot(kind='barh', stacked=True, ax=axes[0])
axes[0].set_xlabel('Adheres to Value')
axes[0].set_ylabel('Count')
axes[0].set_title('Resource = High')
axes[0].legend(title='Adheres to Value')

# Plot the data for Mid resource
grouped_data_mid.plot(kind='barh', stacked=True, ax=axes[1])
axes[1].set_xlabel('Adheres to Value')
axes[1].set_ylabel('Count')
axes[1].set_title('Resource = Mid')
axes[1].legend(title='Adheres to Value')

# Plot the data for Low resource
grouped_data_low.plot(kind='barh', stacked=True, ax=axes[2])
axes[2].set_xlabel('Adheres to Value')
axes[2].set_ylabel('Count')
axes[2].set_title('Resource = Low')
axes[2].legend(title='Adheres to Value')

plt.tight_layout()
plt.show()
